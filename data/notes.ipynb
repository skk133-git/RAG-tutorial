# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Attention & Transformers Notes\n",
    "\n",
    "This notebook contains explanations and code examples for attention mechanisms and transformers."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Attention Mechanism\n",
    "- Queries (Q), Keys (K), Values (V)\n",
    "- Attention score = softmax(QK^T / sqrt(d_k))\n",
    "- Weighted sum of Values based on attention scores"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "import torch\n",
    "import torch.nn as nn\n",
    "\n",
    "# Example: Scaled Dot-Product Attention\n",
    "def attention(Q, K, V):\n",
    "    d_k = Q.size(-1)\n",
    "    scores = torch.matmul(Q, K.transpose(-2, -1)) / torch.sqrt(torch.tensor(d_k, dtype=torch.float32))\n",
    "    weights = torch.nn.functional.softmax(scores, dim=-1)\n",
    "    return torch.matmul(weights, V)\n",
    "\n",
    "# Example tensors\n",
    "Q = torch.rand(2,3,4)\n",
    "K = torch.rand(2,3,4)\n",
    "V = torch.rand(2,3,4)\n",
    "output = attention(Q,K,V)\n",
    "print(output)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Transformer Overview\n",
    "- Encoder-Decoder structure\n",
    "- Multi-Head Self-Attention\n",
    "- Position-wise Feedforward Networks\n",
    "- Positional Encoding"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.11"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
